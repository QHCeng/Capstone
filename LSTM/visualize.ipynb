# %%
model.eval()
all_preds = []
all_truths = []
all_dates = []  

with torch.no_grad():
    for X, y in tqdm(test_loader, desc="Collecting predictions"):
        X = X.to(device)
        preds = model(X).squeeze().cpu().numpy()
        y = y.cpu().numpy()

        all_preds.extend(preds)
        all_truths.extend(y)


y_pred = np.array(all_preds)
y_true = np.array(all_truths)

# %%
plt.figure(figsize=(12, 5))
plt.plot(y_true, label="Actual", marker='o', alpha=0.8)
plt.plot(y_pred, label="Predicted", marker='x', alpha=0.8)
plt.title("Actual vs Predicted - Test Set")
plt.xlabel("Sample Index (Time)")
plt.ylabel("Monthly Spending")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.scatter(y_true, y_pred, alpha=0.6)
plt.plot([y_true.min(), y_true.max()],
         [y_true.min(), y_true.max()],
         'r--', label="Ideal")
plt.title("Predicted vs Actual (Test Set)")
plt.xlabel("Actual Spending")
plt.ylabel("Predicted Spending")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
residuals = y_pred - y_true

plt.figure(figsize=(12, 4))
plt.plot(residuals, marker='o', alpha=0.7)
plt.axhline(0, color='red', linestyle='--')
plt.title("Residuals Over Time")
plt.xlabel("Sample Index (Time)")
plt.ylabel("Residual (Pred - Actual)")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7, 4))
plt.hist(residuals, bins=30, alpha=0.7, edgecolor='black')
plt.title("Residual Distribution")
plt.xlabel("Residual")
plt.ylabel("Count")
plt.grid(True)
plt.tight_layout()
plt.show()
